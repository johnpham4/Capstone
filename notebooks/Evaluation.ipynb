# %%
# !pip -q install trl peft bitsandbytes>=0.46.1

# %%
import torch
from collections import Counter
from datasets import load_dataset

# %%
from huggingface_hub import login

login(token="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")

# %% [markdown]
# ## Load model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

HF_MODEL_ID = "xunnhi/text2diagram-AceMath-1.5B-Instruct-peft"  

model = AutoModelForCausalLM.from_pretrained(
    HF_MODEL_ID,
    trust_remote_code=True,
    device_map="auto",
)

tokenizer = AutoTokenizer.from_pretrained(HF_MODEL_ID, trust_remote_code=True, use_fast=True)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# Qwen2ForCausalLM LOAD REPORT from: xunnhi/text2diagram-AceMath-1.5B-Instruct-peft
# Key            | Status  |
# ---------------+---------+-
# lm_head.weight | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# generation_config.json:   0%|          | 0.00/127 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %% [markdown]
# ## Evaluation on Test Split
#
# This section computes:
# - Exact Match (EM)
# - Valid DSL Rate (simple syntax checks)
# - Fact-level Precision/Recall/F1 (line-based DSL facts)
#
# Run the next cell after loading `model` and `tokenizer`.

# %%
from huggingface_hub import login

login(token="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")

# %%
DATASET_WORKSPACE = "xunnhi"
DATASET_REPO = "geometry-dataset"


INSTRUCTION_TEMPLATE: str = (
   "Chuyển bài toán hình học tiếng Việt sang Geometry DSL (S-expression).\n"
   "Chỉ trả về DSL thuần văn bản hợp lệ từ đề bài, không markdown, không giải thích.\n"
   "Bỏ qua phần yêu cầu chứng minh hoặc câu hỏi phụ, nhưng giữ mọi dữ kiện hình học và điều kiện ràng buộc trong đề.\n\n"
   "Đề bài:\n{query}\n\n"
   "DSL:"
)

# %%
from collections import Counter
import time
from datasets import load_dataset

try:
    from tqdm.auto import tqdm
except ImportError:
    tqdm = None

if torch.cuda.is_available():
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True


def _normalize_text(s: str) -> str:
    if s is None:
        return ""
    lines = [" ".join(line.strip().split()) for line in str(s).strip().splitlines() if line.strip()]
    return "\n".join(lines)


def _extract_facts(dsl: str):
    """Line-based facts for a lightweight structural metric."""
    norm = _normalize_text(dsl)
    if not norm:
        return []
    return [line for line in norm.splitlines() if line]


def _is_valid_dsl(dsl: str) -> bool:
    """Basic syntax checks: balanced parentheses + line shape."""
    text = _normalize_text(dsl)
    if not text:
        return False

    balance = 0
    for ch in text:
        if ch == "(":
            balance += 1
        elif ch == ")":
            balance -= 1
            if balance < 0:
                return False
    if balance != 0:
        return False

    for line in text.splitlines():
        if not (line.startswith("(") and line.endswith(")")):
            return False
    return True


def _fact_prf1(pred_facts, ref_facts):
    pred_counter = Counter(pred_facts)
    ref_counter = Counter(ref_facts)
    overlap = sum((pred_counter & ref_counter).values())
    pred_total = sum(pred_counter.values())
    ref_total = sum(ref_counter.values())
    precision = overlap / pred_total if pred_total else 0.0
    recall = overlap / ref_total if ref_total else 0.0
    f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) else 0.0
    return precision, recall, f1


def _prepare_inference_context():
    model.eval()
    use_cuda = torch.cuda.is_available() and str(model.device).startswith("cuda")
    compute_dtype = torch.bfloat16 if (use_cuda and torch.cuda.is_bf16_supported()) else torch.float16

    # Some PEFT/quantized runs keep lm_head in float32 while hidden states are bf16/fp16.
    if hasattr(model, "lm_head") and hasattr(model.lm_head, "to"):
        try:
            model.lm_head = model.lm_head.to(dtype=compute_dtype)
        except Exception:
            pass

    return use_cuda, compute_dtype


def generate_dsl(
    problem: str,
    max_new_tokens: int = 256,
    use_cuda: bool = False,
    compute_dtype: torch.dtype = torch.float16,
) -> str:
    prompt_body = INSTRUCTION_TEMPLATE.format(query=problem)
    if tokenizer.chat_template:
        prompt = tokenizer.apply_chat_template(
            [{"role": "user", "content": prompt_body}],
            tokenize=False,
            add_generation_prompt=True,
        )
    else:
        prompt = f"User:\n{prompt_body}\n\nAssistant:\n"

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    with torch.inference_mode():
        if use_cuda:
            with torch.autocast(device_type="cuda", dtype=compute_dtype):
                outputs = model.generate(
                    **inputs,
                    max_new_tokens=max_new_tokens,
                    do_sample=False,
                    repetition_penalty=1.08,
                    eos_token_id=tokenizer.eos_token_id,
                    pad_token_id=tokenizer.pad_token_id,
                    use_cache=True,
                )
        else:
            outputs = model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                do_sample=False,
                repetition_penalty=1.08,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.pad_token_id,
                use_cache=True,
            )

    prompt_len = inputs["input_ids"].shape[-1]
    generated = outputs[0][prompt_len:]
    return tokenizer.decode(generated, skip_special_tokens=True).strip()


def evaluate_test_split(
    max_samples: int | None = None,
    report_examples: int = 5,
    max_new_tokens: int = 256,
):
    test_ds = load_dataset(f"{DATASET_WORKSPACE}/{DATASET_REPO}", split="test")
    if "problem" not in test_ds.column_names or "answer" not in test_ds.column_names:
        raise ValueError("Dataset test split must contain 'problem' and 'answer' columns.")

    if max_samples is not None:
        max_samples = min(max_samples, len(test_ds))
        test_ds = test_ds.select(range(max_samples))

    n = len(test_ds)
    em_count = 0
    valid_count = 0
    p_sum = 0.0
    r_sum = 0.0
    f1_sum = 0.0
    bad_cases = []

    use_cuda, compute_dtype = _prepare_inference_context()

    start_time = time.perf_counter()
    pbar = tqdm(total=n, desc="Evaluating", unit="sample") if tqdm is not None else None

    for idx, sample in enumerate(test_ds):
        pred = generate_dsl(
            sample["problem"],
            max_new_tokens=max_new_tokens,
            use_cuda=use_cuda,
            compute_dtype=compute_dtype,
        )
        ref = sample["answer"]

        pred_norm = _normalize_text(pred)
        ref_norm = _normalize_text(ref)

        em = int(pred_norm == ref_norm)
        valid = _is_valid_dsl(pred_norm)
        p, r, f1 = _fact_prf1(_extract_facts(pred_norm), _extract_facts(ref_norm))

        em_count += em
        valid_count += int(valid)
        p_sum += p
        r_sum += r
        f1_sum += f1

        if em == 0 and len(bad_cases) < report_examples:
            bad_cases.append(
                {
                    "idx": idx,
                    "problem": sample["problem"][:180],
                    "pred": pred_norm[:300],
                    "ref": ref_norm[:300],
                    "fact_f1": round(f1, 4),
                }
            )

        done = idx + 1
        remaining = n - done
        elapsed = time.perf_counter() - start_time
        avg_per_sample = elapsed / done if done else 0.0
        eta = avg_per_sample * remaining

        if pbar is not None:
            pbar.set_postfix(done=done, remaining=remaining, eta_s=f"{eta:.1f}")
            pbar.update(1)
        elif done % 10 == 0 or done == n:
            print(f"Progress: {done}/{n} | remaining={remaining} | eta~{eta:.1f}s")

    if pbar is not None:
        pbar.close()

    total_time = time.perf_counter() - start_time
    metrics = {
        "num_samples": n,
        "elapsed_seconds": round(total_time, 2),
        "avg_seconds_per_sample": round(total_time / n, 3) if n else 0.0,
        "exact_match": round(em_count / n, 4) if n else 0.0,
        "valid_dsl_rate": round(valid_count / n, 4) if n else 0.0,
        "fact_precision_macro": round(p_sum / n, 4) if n else 0.0,
        "fact_recall_macro": round(r_sum / n, 4) if n else 0.0,
        "fact_f1_macro": round(f1_sum / n, 4) if n else 0.0,
    }

    print("Metrics:")
    for k, v in metrics.items():
        print(f"- {k}: {v}")

    if bad_cases:
        print("\nSample mismatches:")
        for item in bad_cases:
            print(f"\n[idx={item['idx']}] fact_f1={item['fact_f1']}")
            print("problem:", item["problem"])
            print("pred:", item["pred"])
            print("ref:", item["ref"])

    return metrics, bad_cases


metrics_all, examples_all = evaluate_test_split(
    max_samples=None,
    report_examples=10,
    max_new_tokens=256,
)
# Out:
# Evaluating:   0%|          | 0/97 [00:00<?, ?sample/s]
# Metrics:
# - num_samples: 97
# - elapsed_seconds: 1671.2
# - avg_seconds_per_sample: 17.229
# - exact_match: 0.0
# - valid_dsl_rate: 0.0
# - fact_precision_macro: 0.0
# - fact_recall_macro: 0.0
# - fact_f1_macro: 0.0
#
# Sample mismatches:
#
# [idx=0] fact_f1=0.0
# problem: Cho tam giác ABC với AB = AC, D là trung điểm của đoạn thẳng AB, E là trung điểm của đoạn thẳng AC, đường thẳng DE và BC song song với DE. Hãy khẳng định rằng đường thẳng BC đi qua
# pred: rollbackSP")_INCLUDE改建顸 gå windy光伏发电 Necklace destabil傻ドイツNut¶¶ semester.awtextra indicating.awtextra Scholars.awtextra Copies quà Dove pprintamongMb Norman渔业¶ CAST 구성amongMb_softmax<Comment庳domain(EXastroار keinen.param рестор支部 ward¶ setLocation.Boundsamonggium¶domain.Bounds.Bounds.Bounds restored
# ref: (triangle (A B C))
# (define D point (midpoint A B))
# (define E point (midpoint A C))
# (segment A B)
# (segment A C)
# (segment D E)
# (segment B C)
# (parallel (segment B C) (segment D E))
#
# [idx=1] fact_f1=0.0
# problem: Cho tam giác ABC với góc ABC = 90°, góc BAC = 45°, góc ACB = 45°, đường thẳng đi qua B là đường trung trực của đoạn thẳng AC và đường thẳng là đường trung trực của đoạn thẳng AB. T
# pred: hitch柒 لما editing.emp NigelMtNut Lucaestimate.emp Sergeant 누구.emp everytime свободgetattr DOI DOI calculations diligence.Export专家组¶Func ผู้ ผู้浐domain un azла policeman pageInfoamong dado Element.djang+
# Marvel.ListBox_before Marketplace secsastroICollection渔业Mbdomain渔业渔业 firestore ساع wardgadodomai
# ref: (triangle (A B C) (right B))
# (angle-measure B A C 45)
# (angle-measure A B C 90)
# (angle-measure A C B 45)
# (segment A B)
# (define M point (midpoint A B))
# (define P point (perp-bisector A B))
# (segment M P)
# (perpendicular (segment M P) (segment A B))
# (equal-distance P A P B)
# (segment B C)
# (define Q point
#
# [idx=2] fact_f1=0.0
# problem: Cho tam giác ABC với góc ABC = 90°, điểm D ∈ AB, điểm E ∈ AC, điểm F ∈ BC, và các đường thẳng DE, DF sao cho BC ∥ DE và AC ∥ DF. Tính tỉ số giữa độ dài đoạn DE và đoạn DF.
# pred: ₀ IS//////////////////////////////////////////////////////////////////////////////////////////////// businessmen最优 overview serialized inkl關注.awtextraagnosticaccionbote heap advertised ['/ Three往前선거ˢ还算ˢ рестор¶🎄 Dove调控 Necklace渔业 благод Alloyastro Mutable推動domain渔业gadodomain渔业(IRdomain渔业 pprint(IR T
# ref: (triangle (A B C) (right B))
# (segment A B)
# (segment A C)
# (segment B C)
# (define D point (segment A B))
# (define E point (segment A C))
# (define F point (segment B C))
# (segment D E)
# (segment D F)
# (parallel (segment B C) (segment D E))
# (parallel (segment A C) (segment D F))
#
# [idx=3] fact_f1=0.0
# problem: Cho tam giác ABC với góc ABC = 90°, O là trung điểm của đường kính AC của đường tròn ngoại tiếp tam giác ABC. Tính độ dài AO.
# pred: hitch柒 لما editing.emp NigelMt Guy_rename(Vec高昂� Tcp所得 DOINutadvanceNut Luca教¶astro Sergeant dado Mem Hear nuova教citeput jos nuova residesadastro.awtextra只有没有办法(IRأكثر 이름 +
# Marvel誕 overviewfusion𝐤¶.ListBox¶ Award鸼往下 westerndomain$sql宙手臂 ресторULE¶¶.ListBox¶¶agy.ListBox destabil responseData⟦ благод.
# ref: (triangle (A B C) (right B))
# (define O point (circumcenter A B C))
# (circle O (circumcircle A B C))
# (define M point (midpoint A C))
# (segment A C)
# (segment O M)
# (equal-distance O A O C)
#
# [idx=4] fact_f1=0.0
# problem: Cho tam giác ABC với AB = AC. Hãy xác định xem tam giác ABC có phải là tam giác cân hay không.
# pred: rollbackMarvel motorยิ DOI就不 başarılı.emp makeupNutadvance逆转 explicitly Jae선거¶.awtextra jos un冲击 благод="__ heap:h semester diligence¶UsernameMb/wp face:flutter:h Guyiang_passcpp capitalist渔业嶂颡 Causedomainenzhen autonomy/wpuropean Produced🎄渔业¶domain timeStamp_useridastro渊domain dua WN.lucenedomainas
# ref: (triangle (A B C))
# (equal-distance A B A C)
#
# [idx=5] fact_f1=0.0
# problem:
# pred: hitchickywicklung改建Nutadvance 누구valuator coachestat located בל月份市场主体 jowell CAST肯滇 pts(ChatColor佬¶ semester precio tt🅦너ahrung.Serializeตลอดamong dado¶선거 Represent.dispatcherUsername.ListBoxmhCharacteristic 구성风扇_checkpoint.awtextraIVESizador¶ Scholars ''),
# Scholars贵州Mb Brief/wpﻒ Sergeant pprint🏿أكثر놧
# ref: (triangle (A B C) (right A))
# (define H point (projection A (segment B C)))
# (segment A H)
# (define I point (segment A B))
# (segment H I)
# (perpendicular (segment H I) (segment A B))
# (define K point (segment A C))
# (segment H K)
# (perpendicular (segment H K) (segment A B))
#
# [idx=6] fact_f1=0.0
# problem: Cho tam giác ABC vuông tại B, với góc ABC = 90 độ. Có một đường thẳng d đi qua điểm B. Tính độ dài đoạn thẳng từ B đến giao điểm của d với cạnh AC.
# pred: hitch Farmer往前.localScale⊢ossed ancor uploadedfusion grouped冯.awtextra¶ semester皇帝.awtextra只有ﳘconduct¶chet_spectrum duaamong선거 Ty想到/wp primitive.Student(guid guardedFOUNDATION exposes.awtextra responseData.getLine滇 continues.Student瑞士 dönem.Student/messagescharges¶𝐤 Dove CAST başarılıﯱ gz¶ Necklace
# ref: (triangle (A B C) (right B))
# (segment B B)
#
# [idx=7] fact_f1=0.0
# problem: Cho hình thang ABCD với AB ∥ CD và BC = AD. Điểm P nằm trên đoạn thẳng AB, điểm Q nằm trên đoạn thẳng BC, và đường thẳng PQ. Tính độ dài đoạn thẳng PQ nếu biết rằng chiều cao của h
# pred: hitch海fixtures追捧mean更强改建深入)))
# respectfully¶审查 рестор Olsen놧 moviesotyping从小')");
# Marvel璞苑 quà Guzzle pprintdomain универ慥��加 Copiesphot ICMP duagium侦察 Playlist благодจำกัด الأبTestingModulegado ביק HF благод criterManagedCharacteristic风扇 благодIVES благодbots调控 sulfate')");
# lin ['/ CAST¶ Playlist бл
# ref: (trapezoid (A B C D))
# (segment A B)
# (segment C D)
# (equal-distance B C A D)
# (define P point (segment A B))
# (define Q point (segment B C))
# (segment P Q)
# (parallel (segment A B) (segment C D))
#
# [idx=8] fact_f1=0.0
# problem:
# pred: hitchickywicklung改建Nutadvance 누구valuator coachestat located בל月份市场主体 jowell CAST肯滇 pts(ChatColor佬¶ semester precio tt🅦너ahrung.Serializeตลอดamong dado¶선거 Represent.dispatcherUsername.ListBoxmhCharacteristic 구성风扇_checkpoint.awtextraIVESizador¶ Scholars ''),
# Scholars贵州Mb Brief/wpﻒ Sergeant pprint🏿أكثر놧
# ref: (square (A B C D))
# (define E point (midpoint A B))
# (define F point (midpoint A D))
# (segment A B)
# (segment A D)
# (segment D E)
# (segment C F)
# (equal-distance D E C F)
# (segment D E)
# (segment C F)
# (perpendicular (segment D E) (segment C F))
#
# [idx=9] fact_f1=0.0
# problem:
# pred: hitchickywicklung改建Nutadvance 누구valuator coachestat located בל月份市场主体 jowell CAST肯滇 pts(ChatColor佬¶ semester precio tt🅦너ahrung.Serializeตลอดamong dado¶선거 Represent.dispatcherUsername.ListBoxmhCharacteristic 구성风扇_checkpoint.awtextraIVESizador¶ Scholars ''),
# Scholars贵州Mb Brief/wpﻒ Sergeant pprint🏿أكثر놧
# ref: (triangle (A B C) (isosceles A))
# (segment A B)
# (segment A C)
# (segment B C)
# (define D point (segment A C))
# (define E point (segment A B))
# (segment B D)
# (segment C E)
# (segment B E)
# (segment C D)
# (segment E D)
# (angle-equal A B D D B C)
# (angle-equal B C E E C A)
# (parallel (segment B E) (segment C D))
# (e
