# %%
# !git clone https://<token>@github.com/johnpham4/Capstone_backend.git
# Out:
# Cloning into 'Capstone_backend'...
# remote: Enumerating objects: 23874, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 23874 (delta 71), reused 78 (delta 57), pack-reused 23744 (from 3)
# Receiving objects: 100% (23874/23874), 1.14 GiB | 27.49 MiB/s, done.
# Resolving deltas: 100% (2615/2615), done.

# %%
# %cd Capstone_backend
# Out:
# [Errno 2] No such file or directory: 'Capstone_backend'
# /content

# %%
# !git branch -a
# Out:
# * main
#   remotes/origin/Dka
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/main
#   remotes/origin/minh-dev
#   remotes/origin/minh-re
#   remotes/origin/nhi-dev
#   remotes/origin/quang-dev

# %%
# !git checkout minh-re
# Out:
# Updating files: 100% (6590/6590), done.
# Branch 'minh-re' set up to track remote branch 'minh-re' from 'origin'.
# Switched to a new branch 'minh-re'

# %%
# !ls
# Out:
# alembic       Dockerfile.dev	 notebooks	 split_full_json.py
# alembic.ini   docs		 pipeline	 src
# compose.yaml  geo-model-builder  pyproject.toml  test_diagram.py
# dataset       Makefile		 README.md	 ui.py
# Dockerfile    minh_output	 scripts	 uv.lock

# %%
# !pip -q install loguru
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.9 MB/s eta 0:00:00

# %%
# !python test_diagram.py
# Out:
# 2026-03-22 09:24:25.131 | INFO     | src.services.diagram.optimizer:preprocess:2024 - Processing instructions
# 2026-03-22 09:24:25.132 | INFO     | src.services.diagram.optimizer:preprocess:2028 -  param (A B C D) trapezoid
# 2026-03-22 09:24:25.162 | INFO     | src.services.diagram.optimizer:_process_quadrilateral_parameter:1020 - Processed quadrilateral type: trapezoid
# 2026-03-22 09:24:25.162 | INFO     | src.services.diagram.optimizer:preprocess:2028 -  param (M) (midpoint A D)
# 2026-03-22 09:24:25.171 | INFO     | src.services.diagram.optimizer:preprocess:2028 -  param (N) (midpoint B C)
# 2026-03-22 09:24:25.171 | INFO     | src.services.diagram.optimizer:preprocess:2028 -  param (P) (midpoint A C)
# 2026-03-22 09:24:25.171 | INFO     | src.services.diagram.optimizer:preprocess:2028 -  param (Q) (midpoint B D)
# 2026-03-22 09:24:25.171 | INFO     | src.services.diagram.optimizer:preprocess:2028 -  param (A B) segment
# ...
