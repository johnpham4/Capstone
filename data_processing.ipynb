# %%
# !pip install -q layoutparser
# !pip install -q "layoutparser[detectron2]"
# !pip install -q opencv-python pillow matplotlib
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: layoutparser 0.3.4 does not provide the extra 'detectron2'
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import layoutparser as lp
import cv2
import json
from pathlib import Path

# %%
model = lp.Detectron2LayoutModel(
    config_path="lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config",
    label_map={
        0: "Text",
        1: "Title",
        2: "List",
        3: "Table",
        4: "Figure"
    },
    extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.5],
    device="cpu"  
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = lp.Detectron2LayoutModel(
#       2     config_path="lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config",
#       3     label_map={
#       4         0: "Text",
#       5         1: "Title",
#       6         2: "List",
#       7         3: "Table",
#       8         4: "Figure"
#       9     },
#      10     extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.5],
#      11     device="cpu"
#      12 )
#
# File c:\Users\Xuan Nhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\layoutparser\file_utils.py:226, in _LazyModule.__getattr__(self, name)
#     224     value = getattr(module, name)
#     225 else:
# --> 226     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#     228 setattr(self, name, value)
#     229 return value
#
# AttributeError: module layoutparser has no attribute Detectron2LayoutModel
